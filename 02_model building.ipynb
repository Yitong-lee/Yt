# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import tensorflow as tf
from tensorflow import keras

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("train_cleaned.csv")
df.head()
# Out:
#    review_rating  number_of_photos  helpful_vote  reviewer_ID  fake_asin  \
# 0              5                 0             0       380263          1
# 1              5                 0             0       845137          0
# 2              5                 0             0       659759          0
# 3              5                 0             1        73493          0
# 4              4                 0             0       714841          0
#
#    fake_review  product_ID  review_ID  \
# 0            1         389      34510
# 1            0          99     381688
# 2            0         107     417933
# 3            0          66     166465
# 4            0          14     289006
#
#                                               review  year  month  day  \
# 0  super product husband hard time sleep first ni...  2020      4   13
# 1                                       sturdi rving  2020      8   29
# 2            five star dramat improv toe nail appear  2018      2   27
# 3  great portabl irrig recent got brace need work...  2012      5   16
# 4       four star salad shooter work great save time  2015      1    5
#
#    is_weekday  polarity  subjectivity  labeled_product_id
# 0           1  0.315278      0.565278                 389
# 1           0  0.000000      0.000000                   0
# 2           1  0.000000      0.000000                   0
# 3           1  0.269388      0.631293                   0
# 4           1  0.800000      0.750000                   0

# %%
X = df.drop(['reviewer_ID', 'fake_asin', 'product_ID', 'review_ID', 'review', 'fake_review'], axis = 1)

# get dummies
X = pd.get_dummies(X, columns=['labeled_product_id'])
X = X.drop(['labeled_product_id_0'], axis = 1)

# scaling
X = X.apply(pd.to_numeric)
stander = StandardScaler()

X = stander.fit_transform(X)

# %%
y = df['fake_review']

# %%
model = keras.models.Sequential()


model.add(keras.layers.Dense(2048, activation='relu', input_dim=X.shape[1]))

model.add(keras.layers.Dense(1024, activation='relu'))

model.add(keras.layers.Dense(512, activation='relu'))

model.add(keras.layers.Dense(256, activation='relu'))

model.add(keras.layers.Dense(128, activation='relu'))

model.add(keras.layers.Dense(1, activation='sigmoid'))

# %%
model.compile(loss=keras.losses.BinaryFocalCrossentropy(), optimizer='adam', metrics=['accuracy'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 12343)

# %%
# compute the class weights
n_samples = len(y_train)
n_classes = len(np.unique(y_train))
class_counts = np.bincount(y_train)
class_weights = {i: n_samples / (n_classes * class_counts[i]) for i in range(n_classes)}

# fit the model with sample weights
sample_weights = np.array([class_weights[label] for label in y_train])

from keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')

model.fit(X_train, y_train, sample_weight=sample_weights, epochs = 50, validation_split=0.2, batch_size=64)
# Out:
# Epoch 1/50
# 3428/3429 [============================>.] - ETA: 0s - loss: 0.1548 - accuracy: 0.8631WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 122s 35ms/step - loss: 0.1548 - accuracy: 0.8631 - val_loss: 0.1485 - val_accuracy: 0.8796
# Epoch 2/50
# 3429/3429 [==============================] - ETA: 0s - loss: 0.1520 - accuracy: 0.8757WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 110s 32ms/step - loss: 0.1520 - accuracy: 0.8757 - val_loss: 0.1481 - val_accuracy: 0.8848
# Epoch 3/50
# 3429/3429 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.8774WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 109s 32ms/step - loss: 0.1499 - accuracy: 0.8774 - val_loss: 0.1466 - val_accuracy: 0.8898
# Epoch 4/50
# 3429/3429 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 0.8780WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 109s 32ms/step - loss: 0.1488 - accuracy: 0.8780 - val_loss: 0.1468 - val_accuracy: 0.8953
# Epoch 5/50
# 3428/3429 [============================>.] - ETA: 0s - loss: 0.1466 - accuracy: 0.8845WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 108s 31ms/step - loss: 0.1466 - accuracy: 0.8845 - val_loss: 0.1447 - val_accuracy: 0.9041
# Epoch 6/50
# 3429/3429 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.8798WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 107s 31ms/step - loss: 0.1467 - accuracy: 0.8798 - val_loss: 0.1449 - val_accuracy: 0.9154
# Epoch 7/50
# 3428/3429 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.8859WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] -
50
# 3429/3429 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.8652WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 112s 33ms/step - loss: 0.1373 - accuracy: 0.8652 - val_loss: 0.1413 - val_accuracy: 0.8569
# Epoch 45/50
# 3429/3429 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.8624WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 107s 31ms/step - loss: 0.1370 - accuracy: 0.8624 - val_loss: 0.1417 - val_accuracy: 0.8743
# Epoch 46/50
# 3429/3429 [==============================] - ETA: 0s - loss: 0.1369 - accuracy: 0.8659WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 109s 32ms/step - loss: 0.1369 - accuracy: 0.8659 - val_loss: 0.1435 - val_accuracy: 0.8190
# Epoch 47/50
# 3428/3429 [============================>.] - ETA: 0s - loss: 0.1384 - accuracy: 0.8618WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 123s 36ms/step - loss: 0.1384 - accuracy: 0.8618 - val_loss: 0.1431 - val_accuracy: 0.8416
# Epoch 48/50
# 3428/3429 [============================>.] - ETA: 0s - loss: 0.1370 - accuracy: 0.8635WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 116s 34ms/step - loss: 0.1370 - accuracy: 0.8635 - val_loss: 0.1412 - val_accuracy: 0.8609
# Epoch 49/50
# 3429/3429 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.8601WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 109s 32ms/step - loss: 0.1373 - accuracy: 0.8601 - val_loss: 0.1422 - val_accuracy: 0.8376
# Epoch 50/50
# 3429/3429 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.8595WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 3429/3429 [==============================] - 108s 32ms/step - loss: 0.1358 - accuracy: 0.8595 - val_loss: 0.1432 - val_accuracy: 0.8556

# %%
from sklearn.metrics import confusion_matrix
# Get the predicted labels and true labels
y_pred = model.predict(X_test)

def my_fuc(x):
    if x < 0.65:
        return 0
    else:
        return 1
    
y_pred = np.array([my_fuc(x) for x in y_pred])

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Print the confusion matrix
print(cm)

from sklearn.metrics import f1_score
print(f1_score(y_test, y_pred))

from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
# 3674/3674 [==============================] - 14s 4ms/step
# [[107957   3568]
#  [  3644   2394]]
# 0.399
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97    111525
#            1       0.40      0.40      0.40      6038
#
#     accuracy                           0.94    117563
#    macro avg       0.68      0.68      0.68    117563
# weighted avg       0.94      0.94      0.94    117563

# %%
df_test = pd.read_csv("test_cleaned.csv")
df_test_sample = df_test.drop(['reviewer_ID', 'product_ID', 'review_ID', 'review', 'fake_asin'], axis = 1)

df_test_sample = pd.get_dummies(df_test_sample, columns=['labeled_product_id'])
df_test_sample = df_test_sample.drop(['labeled_product_id_0'], axis = 1)

stander = StandardScaler()
df_test_sample = stander.fit_transform(df_test_sample)
df_test_sample
# Out:
# array([[-0.16259809,  2.13497981, -0.08194928, ..., -0.11757016,
#         -0.11736967, -0.01172636],
#        [ 0.58756373, -0.17814909, -0.08194928, ..., -0.11757016,
#         -0.11736967, -0.01172636],
#        [ 0.58756373, -0.17814909, -0.08194928, ..., -0.11757016,
#         -0.11736967, -0.01172636],
#        ...,
#        [ 0.58756373, -0.17814909, -0.08194928, ..., -0.11757016,
#         -0.11736967, -0.01172636],
#        [ 0.58756373, -0.17814909, -0.08194928, ..., -0.11757016,
#         -0.11736967, -0.01172636],
#        [ 0.58756373, -0.17814909, -0.08194928, ..., -0.11757016,
#         -0.11736967, -0.01172636]])

# %%
predictions = model.predict(df_test_sample)
predictions
# Out:
# 1364/1364 [==============================] - 6s 4ms/step
# array([[0.46258885],
#        [0.48655397],
#        [0.7712257 ],
#        ...,
#        [0.45819482],
#        [0.41771412],
#        [0.5029743 ]], dtype=float32)

# %%
df_test["fake_review"] = predictions

# %%
output = df_test[["review_ID", "fake_review"]]

# %%
output['fake_review'] = output['fake_review'].apply(lambda x: 0 if x < 0.65 else 1)

# %%
output.to_csv('result.csv', index=False)
